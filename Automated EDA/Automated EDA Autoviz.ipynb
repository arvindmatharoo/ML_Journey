# %%
 # !pip install autoviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached narwhals-1.48.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ---------------------------------------- 0.0/125.4 MB ? eta -:--:--
#     --------------------------------------- 2.9/125.4 MB 15.2 MB/s eta 0:00:09
#    - -------------------------------------- 6.0/125.4 MB 14.7 MB/s eta 0:00:09
#    -- ------------------------------------- 7.1/125.4 MB 11.2 MB/s eta 0:00:11
#    --- ------------------------------------ 10.2/125.4 MB 12.0 MB/s eta 0:00:10
#    ---- ----------------------------------- 13.4/125.4 MB 12.5 MB/s eta 0:00:09
#    ---- ----------------------------------- 13.6/125.4 MB 12.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 13.6/125.4 MB 12.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 13.6/125.4 MB 12.6 MB/s eta 0:00:09
# ...

# %%
import seaborn as sns

# %%
df= sns.load_dataset('tips')

# %%
df.to_csv('tips.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
dft = AV.AutoViz('tips.csv')
# Out:
# Shape of your Data Set loaded: (244, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0']
# ...
