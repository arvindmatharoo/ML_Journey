# %%
# !pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      -------------------------------------- 642.7/642.7 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/15.0 MB ? eta -:--:--
#    -------- ------------------------------- 3.1/15.0 MB 16.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.3/15.0 MB 15.5 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/15.0 MB 15.1 MB/s eta 0:00:01
#    --------------------------------- ------ 12.6/15.0 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.0/15.0 MB 13.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import dtale

# %%
import seaborn as sns 
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://laptop:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
