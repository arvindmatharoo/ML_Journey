# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\arvin\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\arvin\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
#extract data from the csv file

# %%
csv_file = pd.read_csv("friends.csv")

# %%
print(csv_file)
# Out:
#    Unnamed: 0    name  marks        city
# 0           0   harry     92      rampur
# 1           1   rohan     34     kolkata
# 2           2  skillf     23    bareilly
# 3           3   shubh     44  antarctica

# %%
#extract data from the excel file

# %%
excel_file = pd.read_excel("Book1.xlsx" , sheet_name = 'Sheet1')

# %%
excel_file
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0      Name   roll no.       class       year       role     marks        city
# 1     Mohit        1234        CE3        2nd    Student         95   Ludhiana
# 2      Naman       2123        CE4        2nd    Student         66  Jalandhar
# 3     Muskan       1412        CE5        2nd    Student         99     Nangal
# 4      Rohan       4123        CE6        2nd    Student         95        Una
