# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', None],
    'Age': [25, None, 35, 40, 28],
    'City': ['New York', 'Los Angeles', None, 'Houston', 'Chicago']
}

# %%
df = pd.DataFrame(data)

# %%
df.fillna(0) #replace with 0
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   0.0  Los Angeles
# 2  Charlie  35.0            0
# 3    David  40.0      Houston
# 4        0  28.0      Chicago

# %%
df.dropna() #deleting elements with nan
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   0.0  Los Angeles
# 2  Charlie  35.0            0
# 3    David  40.0      Houston
# 4        0  28.0      Chicago
