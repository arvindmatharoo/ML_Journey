# %%
import numpy as np

# %%
array = np.array([1,2,3,4,5,6])

# %%
print(array)
# Out:
# [1 2 3 4 5 6]

# %%
print(array[0])
# Out:
# 1

# %%
print(array[ : 4 ])
# Out:
# [1 2 3 4]

# %%
arr1 = array.reshape(3,2,1)

# %%
print(arr1)
# Out:
# [[[1]
#   [2]]
#
#  [[3]
#   [4]]
#
#  [[5]
#   [6]]]
